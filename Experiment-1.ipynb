# %%
from google.colab import drive

drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
print("Hello World")
# Out:
# Hello World

# %%
seconds_in_a_day=24*60*60
seconds_in_a_day
# Out:
# 86400

# %%
a=[5,64,9]
sum(a)
# Out:
# 78

# %%
import pandas as pd
import numpy as np
import keras

# %%
df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/Downloads/addresses.csv', encoding= 'unicode_escape')
df
# Out:
#                     John       Doe  ...   NJ  08075
# 0                   Jack  McGinnis  ...   PA   9119
# 1          John "Da Man"    Repici  ...   NJ   8075
# 2                Stephen     Tyler  ...   SD  91234
# 3                    NaN  Blankman  ...   SD    298
# 4  Joan "the bone", Anne       Jet  ...   CO    123
#
# [5 rows x 6 columns]

# %%
print(list(df))
# Out:
# ['John', 'Doe', '120 jefferson st.', 'Riverside', ' NJ', ' 08075']

# %%
print(df.dtypes)
# Out:
# John                 object
# Doe                  object
# 120 jefferson st.    object
# Riverside            object
#  NJ                  object
#  08075                int64
# dtype: object
